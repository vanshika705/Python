# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

iris = pd.read_csv(r"C:\Users\hp\OneDrive\Desktop\CSI\Iris.csv")
sns.pairplot(iris, hue="Species", palette="Set1", diag_kind="hist")
plt.suptitle("Iris Pairwise Scatter Matrix", y=1.02)
plt.show()
